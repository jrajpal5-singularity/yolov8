# %%
from ultralytics import YOLO

# %%
from ultralytics.yolo.v8.detect.predict import DetectionPredictor
import cv2

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.predict(source="0",show=True)
print(results)
key = cv2.waitKey(1)
if key == 27:
    cv2.destroyAllWindows()
    break
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 321.2ms
# 0: 480x640 1 person, 1 bottle, 198.9ms
# 0: 480x640 1 person, 176.8ms
# 0: 480x640 1 person, 174.3ms
# 0: 480x640 1 person, 1 bottle, 171.9ms
# 0: 480x640 1 person, 1 bottle, 159.6ms
# 0: 480x640 1 person, 185.8ms
# 0: 480x640 1 person, 159.7ms
# 0: 480x640 1 person, 163.7ms
# 0: 480x640 1 person, 171.8ms
# 0: 480x640 1 person, 1 bottle, 156.0ms
# 0: 480x640 1 person, 159.4ms
# 0: 480x640 1 person, 158.6ms
# 0: 480x640 1 person, 160.3ms
# 0: 480x640 1 person, 1 bottle, 164.7ms
# 0: 480x640 1 person, 161.7ms
# 0: 480x640 1 person, 160.1ms
# 0: 480x640 1 person, 163.3ms
# 0: 480x640 1 person, 157.2ms
# 0: 480x640 1 person, 1 bottle, 170.6ms
# 0: 480x640 1 person, 162.1ms
# 0: 480x640 1 person, 160.4ms
# 0: 480x640 1 person, 159.9ms
# 0: 480x640 1 person, 160.1ms
# 0: 480x640 1 person, 148.0ms
# 0: 480x640 1 person, 161.1ms
# 0: 480x640 1 person, 1 bottle, 161.2ms
# 0: 480x640 1 person, 1 bottle, 161.2ms
# 0: 480x640 1 person, 1 bottle, 162.7ms
# 0: 480x640 1 person, 143.2ms
# 0: 480x640 1 person, 156.7ms
# 0: 480x640 1 person, 159.8ms
# 0: 480x640 1 person, 1 bottle, 160.4ms
# 0: 480x640 1 person, 1 bottle, 159.0ms
# 0: 480x640 1 person, 159.1ms
# 0: 480x640 1 person, 140.0ms
# 0: 480x640 1 person, 170.3ms
# 0: 480x640 1 person, 171.2ms
# 0: 480x640 1 person, 159.8ms
# 0: 480x640 1 person, 160.9ms
# 0: 480x640 1 person, 160.5ms
# 0: 480x640 1 person, 1 bottle, 158.6ms
# 0: 480x640 1 person, 160.0ms
# 0: 480x640 1 person, 1 bottle, 162.9ms
# 0: 480x640 1 person, 1 bottle, 162.6ms
# 0: 480x640 1 person, 154.8ms
# 0: 480x640 1 person, 1 bottle, 159.6ms
# 0: 480x640 1 person, 162.7ms
# 0: 480x640 1 person, 156.7ms
# 0: 480x640 1 person, 1 bottle, 159.5ms
# 0: 480x640 1 person, 157.5ms
# 0: 480x640 1 person, 249.9ms
ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23220\3430973967.py in <module>
# ----> 1 results = model.predict(source="0",show=True)
#       2 print(results)
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\yolo\engine\model.py in predict(self, source, stream, **kwargs)
#     250         else:  # only update args if predictor is already setup
#     251             self.predictor.args = get_cfg(self.predictor.args, overrides)
# --> 252         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     253
#     254     def track(self, source=None, stream=False, persist=False, **kwargs):
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\yolo\engine\predictor.py in __call__(self, source, model, stream)
#     155             return self.stream_inference(source, model)
#     156         else:
# --> 157             return list(self.stream_inference(source, model))  # merge list of Result into one
#     158
#     159     def predict_cli(self, source=None, model=None):
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\autograd\grad_mode.py in generator_context(*args, **kwargs)
#      62                         # Pass the last request to the generator and get its response
#      63                         with self.clone():
# ---> 64                             response = gen.send(request)
#      65
#      66             # We let the exceptions raised above by the generator's `.throw` or
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\yolo\engine\predictor.py in stream_inference(self, source, model)
#     219             # Inference
#     220             with self.dt[1]:
# --> 221                 preds = self.model(im, augment=self.args.augment, visualize=visualize)
#     222
#     223             # Postprocess
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\nn\autobackend.py in forward(self, im, augment, visualize)
#     311
#     312         if self.pt or self.nn_module:  # PyTorch
# --> 313             y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     314         elif self.jit:  # TorchScript
#     315             y = self.model(im)
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\nn\tasks.py in forward(self, x, augment, profile, visualize)
#     203         if augment:
#     204             return self._forward_augment(x)  # augmented inference, None
# --> 205         return self._forward_once(x, profile, visualize)  # single-scale inference, train
#     206
#     207     def _forward_augment(self, x):
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\nn\tasks.py in _forward_once(self, x, profile, visualize)
#      56             if profile:
#      57                 self._profile_one_layer(m, x, dt)
# ---> 58             x = m(x)  # run
#      59             y.append(x if m.i in self.save else None)  # save output
#      60             if visualize:
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\nn\modules.py in forward(self, x)
#     219     def forward(self, x):
#     220         """Forward pass of a YOLOv5 CSPDarknet backbone layer."""
# --> 221         y = list(self.cv1(x).chunk(2, 1))
#     222         y.extend(m(y[-1]) for m in self.m)
#     223         return self.cv2(torch.cat(y, 1))
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\yolo8\lib\site-packages\ultralytics\nn\modules.py in forward_fuse(self, x)
#      38     def forward_fuse(self, x):
#      39         """Perform transposed convolution of 2D data."""
# ---> 40         return self.act(self.conv(x))
#      41
#      42
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
# --> 463         return self._conv_forward(input, self.weight, self.bias)
#     464
#     465 class Conv3d(_ConvNd):
#
# ~\anaconda3\envs\yolo8\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     458                             _pair(0), self.dilation, self.groups)
#     459         return F.conv2d(input, weight, bias, self.stride,
# --> 460                         self.padding, self.dilation, self.groups)
#     461
#     462     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %%
print(results)
